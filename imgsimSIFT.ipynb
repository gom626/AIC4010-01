# %%
# !pip install opencv-python==3.3.0.10 
# !pip install opencv-contrib-python==3.3.0.10

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from google.colab.patches import cv2_imshow
filename = '/content/A1_A.jpeg'
img = cv2.imread(filename)
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
sift = cv2.xfeatures2d.SIFT_create()
kp = sift.detect(gray,None)
img=cv2.drawKeypoints(gray,kp,None,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=526x526 at 0x7F05FEEE17B8>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread('/content/A1_A.jpeg',0)
img2 = cv2.imread('/content/A1_P.jpeg',0)
orb = cv2.ORB_create()
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1,des2)
print(len(matches))
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:],None,flags=2)
plt.figure(figsize=(20,20))
plt.imshow(img3)
plt.show()
# Out:
# 188

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread('/content/A1_A.jpeg',0)
img2 = cv2.imread('/content/A2_P.jpeg',0)
orb = cv2.ORB_create()
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1,des2)
print(len(matches))
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:],None,flags=2)
plt.figure(figsize=(20,20))
plt.imshow(img3)
plt.show()
# Out:
# 183

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread('/content/A1_A.jpeg',0)
img2 = cv2.imread('/content/A3_P.jpeg',0)
orb = cv2.ORB_create()
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1,des2)
print(len(matches))
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:],None,flags=2)
plt.figure(figsize=(20,20))
plt.imshow(img3)
plt.show()
# Out:
# 206

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread('/content/A1_A.jpeg',0)
img2 = cv2.imread('/content/A4_P.jpeg',0)
orb = cv2.ORB_create()
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1,des2)
print(len(matches))
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:],None,flags=2)
plt.figure(figsize=(20,20))
plt.imshow(img3)
plt.show()
# Out:
# 184
